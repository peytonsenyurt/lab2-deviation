# %% [markdown]
# #**Lab 2 - Types of Graphs**

# %% [markdown]
# By: Peyton Buket Senyurt

# %% [markdown]
# #Deviation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# This graph shows the deviation of the average sum of the losing from the average sum of the winning points for game dates by year from 1985 to 2017. The average is 4188 points which is subtracted from the sum of points each year. The losing points are below the average line and are heat mapped. The most losing points in this interval of time was 3738 points in the year 1985. The winning points are seen above the average line also heat mapped, but this time in the shade of blue. The highest winning points in this interval of time is 4615 points in 1989.

# %% [markdown]
# #Correlation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# This graph demonstrates the correlation between the winning points and the losing points for the academic years from 1984 to 2013. This graph uses a scatterplot with two sets of data. The red points are the accumulated winning points associated with each year and the blue points are the sum of the losing points for each year. Each year has two data points that are placed on a synchronized dual axis. This graph effectively demonstrates that every year there is a larger sum of winning points for the teams than the sum of losing points. Additionally an increasing trend is visible for both the losing points and the winning points.

# %% [markdown]
# #Ranking

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# This is a graph ranking the losing points for the academic years from 1984 to 2016. It effectively demonstrates the which years had higher and lower total losing points. This graph uses bar graph because it makes it easy to compare the total losing points for a specific year to the year before and after. For example in the year the years 1998 and 1999 stand out to me because they show a lower ranking for the sum of losing points compared to the majority of the academic years.

# %% [markdown]
# #Distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# For the distribution chart I used a box and whisker plot to demmonstrate the distribution of the sum of the losing points and the sum of the wining points. The losing points are seen as the blue dots on the graph and the winning points are the red points. This graph is very useful to display distribution because as you can see the median for both losing points and winning points are both in the 250 range. This is useful to compare medians for these two opposite measures. The interquartile range for these data points is about 100 to 580. Additionally the box plot shows the outliers, minimum and maximum. The winning points are the maximum and the losing points are the minimum. The distance of the maximum from the median is much larger than the distance of the minimum from the median.

# %% [markdown]
# #Change Over Time

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# This change over time graph uses academic year as colums and winning points as the rows. It demonstrates change over time using a line graphs for a long period of time, from 1984 to 2016. Line graphs are good to compare changes over the same period of time because the slope has a meaning. When the slope is positive that means that as the year increases the winning points also increase. Whereas a negative slope demonstrate that the winning points are decreasing over time. This graph demonstrates that the winning points have increased from 1984 to 2016.

# %% [markdown]
# #Magnitude

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# To demonstrate the magnitude of the losing points compared to the winning points in the academic years 1990 to 1995 I used a vertical double bar chart. The blue bars are the losing points and the red bars are the winning points in the league. The winning points for each year are at a greater height than th elosing points. This indicates that the magnitude of winning points is larger than that of losing points. Every year the winning points are a little larger or shy of 5000 points.

# %% [markdown]
# #Part-to-hole

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**

# %% [markdown]
# This graph demonstrates the top ten teams with the highest winning points for all the years in the data set. A pie chart is a great visual aid for this type of data because each slice makes up a whole 100%. It is easy to compare the slices by their size to see which teams win the most points. Additionally to make it easier to distinguish between the team, I color coded and labeled each team with their team name and the percentage of the total winning points they make up. The Tigers and the Wildcats are tied for number one  at 19.19% of the winning points for the top ten teams.
